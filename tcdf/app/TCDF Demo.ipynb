# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data pod_level_data_cpu_usage.csv --plot --cuda
# Out:
# Arguments: Namespace(cuda=True, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth=None, data=['pod_level_data_cpu_usage.csv'])
#
#  Dataset:  pod_level_data_cpu_usage.csv
#
#  Analysis started for target:  adservice-7df8c84f69-zgsdx
# Epoch:  1 [0%] 	Loss: 0.026485
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  alertmanager-main-0
# Epoch:  1 [0%] 	Loss: 0.025780
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [148, 147]
# Validated causes:  []
#
#  Analysis started for target:  appmesh-controller-6f9b95b4df-8hpjl
# Epoch:  1 [0%] 	Loss: 0.026372
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-load-balancer-controller-69bd799c8c-489sn
# Epoch:  1 [0%] 	Loss: 0.025821
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [144, 147, 148, 127, 128]
# Validated causes:  []
#
#  Analysis started for target:  aws-load-balancer-controller-69bd799c8c-8mmpq
# Epoch:  1 [0%] 	Loss: 0.025500
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [148, 147, 144, 127]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-2fjwc
# Epoch:  1 [0%] 	Loss: 0.025305
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [127, 128, 148, 147]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-4vl7b
# Epoch:  1 [0%] 	Loss: 0.025552
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [144, 127, 147]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-dhqjr
# Epoch:  1 [0%] 	Loss: 0.025461
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-h8428
# Epoch:  1 [0%] 	Loss: 0.025542
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148, 127]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-lpnhv
# Epoch:  1 [0%] 	Loss: 0.025461
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-nlglf
# Epoch:  1 [0%] 	Loss: 0.025607
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 144, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-qvp45
# Epoch:  1 [0%] 	Loss: 0.025485
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-rkkxj
# Epoch:  1 [0%] 	Loss: 0.025614
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  aws-node-sp6j9
# Epoch:  1 [0%] 	Loss: 0.026334
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  blackbox-exporter-7fff97448c-qhnwv
# Epoch:  1 [0%] 	Loss: 0.026503
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  cart-67fd6f756c-5rh47
# Epoch:  1 [0%] 	Loss: 0.026008
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [15]
# Validated causes:  []
#
#  Analysis started for target:  carts-b59845878-bhpkg
# Epoch:  1 [0%] 	Loss: 0.024618
# Epoch: 500 [50%] 	Loss: 0.000024
# Epoch: 1000 [100%] 	Loss: 0.000022
# Potential causes:  [16, 129, 15, 144]
# Validated causes:  []
#
#  Analysis started for target:  carts-b59845878-k8t85
# Epoch:  1 [0%] 	Loss: 0.023528
# Epoch: 500 [50%] 	Loss: 0.000042
# Epoch: 1000 [100%] 	Loss: 0.000038
# Potential causes:  [17, 144]
# Validated causes:  [17]
#
#  Analysis started for target:  carts-b59845878-x57mp
# Epoch:  1 [0%] 	Loss: 0.026010
# Epoch: 500 [50%] 	Loss: 0.000225
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [18, 15]
# Validated causes:  []
#
#  Analysis started for target:  carts-b59845878-zhk8s
# Epoch:  1 [0%] 	Loss: 0.019596
# Epoch: 500 [50%] 	Loss: 0.000078
# Epoch: 1000 [100%] 	Loss: 0.000070
# Potential causes:  [19, 127, 144, 128]
# Validated causes:  [19]
#
#  Analysis started for target:  carts-b59845878-zm9pw
# Epoch:  1 [0%] 	Loss: 0.025127
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [127, 147]
# Validated causes:  []
#
#  Analysis started for target:  carts-db-644ff6b576-4qc2m
# Epoch:  1 [0%] 	Loss: 0.025163
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 127, 144]
# Validated causes:  []
#
#  Analysis started for target:  carts-db-644ff6b576-4wp5k
# Epoch:  1 [0%] 	Loss: 0.025150
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 127, 144, 148]
# Validated causes:  []
#
#  Analysis started for target:  carts-db-644ff6b576-hc2j2
# Epoch:  1 [0%] 	Loss: 0.025052
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [148, 147]
# Validated causes:  []
#
#  Analysis started for target:  carts-db-644ff6b576-nk9bw
# Epoch:  1 [0%] 	Loss: 0.025156
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  carts-db-644ff6b576-rrrrq
# Epoch:  1 [0%] 	Loss: 0.023884
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [127, 147]
# Validated causes:  []
#
#  Analysis started for target:  cartservice-66bdb74f7d-sq84r
# Epoch:  1 [0%] 	Loss: 0.026465
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-685db97474-rppn8
# Epoch:  1 [0%] 	Loss: 0.026450
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-76688dc8c7-24zcl
# Epoch:  1 [0%] 	Loss: 0.026452
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-76688dc8c7-2tcgs
# Epoch:  1 [0%] 	Loss: 0.026449
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-76688dc8c7-gkmc6
# Epoch:  1 [0%] 	Loss: 0.026453
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-76688dc8c7-lx4bv
# Epoch:  1 [0%] 	Loss: 0.026459
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-76688dc8c7-xbgb4
# Epoch:  1 [0%] 	Loss: 0.026373
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-db-d764d45d6-4727d
# Epoch:  1 [0%] 	Loss: 0.026375
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-db-d764d45d6-96krc
# Epoch:  1 [0%] 	Loss: 0.026398
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-db-d764d45d6-dbzd4
# Epoch:  1 [0%] 	Loss: 0.026361
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-db-d764d45d6-dvfnh
# Epoch:  1 [0%] 	Loss: 0.026398
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  catalogue-db-d764d45d6-xwg5z
# Epoch:  1 [0%] 	Loss: 0.025073
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [144, 127]
# Validated causes:  []
#
#  Analysis started for target:  chaos-controller-manager-7f6d6f57b6-jm5sk
# Epoch:  1 [0%] 	Loss: 0.026368
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-controller-manager-7f6d6f57b6-r7sjc
# Epoch:  1 [0%] 	Loss: 0.026395
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-controller-manager-7f6d6f57b6-wpwdm
# Epoch:  1 [0%] 	Loss: 0.026535
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-6dk72
# Epoch:  1 [0%] 	Loss: 0.026533
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-6nfqd
# Epoch:  1 [0%] 	Loss: 0.026536
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-bg5xx
# Epoch:  1 [0%] 	Loss: 0.026537
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-cvj5s
# Epoch:  1 [0%] 	Loss: 0.026537
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-djslh
# Epoch:  1 [0%] 	Loss: 0.026534
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-gb6wd
# Epoch:  1 [0%] 	Loss: 0.026537
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-kbnpl
# Epoch:  1 [0%] 	Loss: 0.026535
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-kgzc5
# Epoch:  1 [0%] 	Loss: 0.026517
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [147, 148]
# Validated causes:  []
#
#  Analysis started for target:  chaos-daemon-mmjxx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /mnt/d/!Observability/promreader/tcdf_docker/runTCDF.py:340
#     338 for dataset in args.data:
#     339     datafiles[dataset]=""
# --> 340 main(datafiles, evaluation=False)
#
# File /mnt/d/!Observability/promreader/tcdf_docker/runTCDF.py:252, in main(datafiles, evaluation)
#     249 print("\n Dataset: ", stringdatafile)
#     251 # run TCDF
# --> 252 allcauses, alldelays, allreallosses, allscores, columns = runTCDF(datafile) #results of TCDF containing indices of causes and effects
#     254 print("\n===================Results for", stringdatafile,"==================================")
#     255 for pair in alldelays:
#
# File /mnt/d/!Observability/promreader/tcdf_docker/runTCDF.py:201, in runTCDF(datafile)
#     199 for c in columns:
#     200     idx = df_data.columns.get_loc(c)
# --> 201     causes, causeswithdelay, realloss, scores = TCDF.findcauses(c, cuda=cuda, epochs=nrepochs,
#     202     kernel_size=kernel_size, layers=levels, log_interval=loginterval,
#     203     lr=learningrate, optimizername=optimizername,
#     204     seed=seed, dilation_c=dilation_c, significance=significance, file=datafile)
#     206     allscores[idx]=scores
#     207     allcauses[idx]=causes
#
# File /mnt/d/!Observability/promreader/tcdf_docker/TCDF.py:65, in findcauses(target, cuda, epochs, kernel_size, layers, log_interval, lr, optimizername, seed, dilation_c, significance, file)
#      61 Y_train = Y_train.unsqueeze(2).contiguous()
#      63 input_channels = X_train.size()[1]
# ---> 65 targetidx = pd.read_csv(file).columns.get_loc(target)
#      67 model = ADDSTCN(targetidx, input_channels, layers, kernel_size=kernel_size, cuda=cuda, dilation_c=dilation_c)
#      68 if cuda:
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/io/parsers/readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:897, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2076, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:
